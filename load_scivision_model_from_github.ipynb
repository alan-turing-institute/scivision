# %% [markdown]
# # Work in Progress
#
# ### Loading a pretrained/prebuilt model from a github repo into `scivision`
#
# Provides an example of loading the following test repo as a scivision Model:
# https://github.com/quantumjot/scivision-test-plugin
#
# The code in the repo performs a simple Gaussian blur on an image.

# %%
from scivision.io import load_pretrained_model

import numpy as np
import matplotlib.pyplot as plt

# %%
model = load_pretrained_model("quantumjot/scivision-test-plugin", allow_install=True)

# %%
model
# Out:
# scivision.PretrainedModel(
#   module='scivision_test_plugin',
#   model='DummyModel',
#   source='https://github.com/quantumjot/scivision-test-plugin.git'
#   pipe='DataPipe(input=<Parameter "X: numpy.ndarray">, output=<Parameter "image: numpy.ndarray">)'
# )

# %%
X = np.random.random(size=(128, 128))

# %%
y = model.predict(X, sigma=3.0)

# optionally, we can also pass keyword arguments to the model
# y = model.predict(X, sigma=10.0)

# %%
plt.figure()
plt.subplot(1, 2, 1)
plt.title('Input data')
plt.imshow(X)
plt.subplot(1, 2, 2)
plt.title('Prediction from model')
plt.imshow(y)
plt.show()
